# %%
import os
from configparser import ConfigParser
path_config_file = os.getcwd().split('docrv2_sroie')[0] + 'docrv2_sroie/' + 'config.ini'
common_variable = ConfigParser()
common_variable.read(path_config_file)

print(common_variable.sections())
print(common_variable['database']['module_path'])
# import lib
import os
from PIL import Image, ImageDraw, ImageFont, ImageTransform
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pickle
from tqdm import tqdm
from glob import glob
import sys
sys.path.append(common_variable['database']['module_path'])
from db_util import *
from db import *
from random import choice
# Out:
# ['database', 'mlflow', 'font']
# /home/dk/docrv2_sroie/modules/database/

# %%
env = open_env('/home/dk/docrv2_sroie/DB/raw_test_task12_2img_denoised')
img = read_bulk_data_from_db(env,'img')

oenv = open_env('/home/dk/docrv2_sroie/DB/raw_test_task12_2img')
oimg = read_bulk_data_from_db(oenv,'img')

# %%
ind = 1
plt.subplots(1,2,figsize=(20,20))
plt.subplot(1,2,1)
plt.imshow(oimg[ind])
plt.subplot(1,2,2)
plt.imshow(img[ind])

# %%
oimg[9]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-40-724108ca0508> in <module>
# ----> 1 oimg[10]
#
# IndexError: list index out of range
